# %% [markdown]
# # 第一回データ分析コンペティション：Titanic
# ![](https://i.imgur.com/rRFchA8.png)

# %% [markdown]
# ## 目的・背景
# 　このコンペティションは、講座で学んだ知識をより実践的に活用できるようにすることを目的に行われます。講義の内容を生かして、自分なりの工夫を加えて取り組んでください。
# また、適切に整形された予測を提出し**Public Leaderboard 上でのスコアが、ベースラインとなる beginner.ipynb のスコアを上回ること**ことは修了要件のひとつであるため、全員が行ってください。
# 今回のテーマである"**Titanic: Machine Learning from Disaster**"（ https://www.kaggle.com/c/titanic ）は、データ分析において登竜門とされているコンペティションです。世界最大のデータ分析コンペティションプラットフォーム**Kaggle**において2012年から開催されています。"Getting Started Prediction Competition"というチュートリアルのような扱いとなっています。データ分析の入門者はこうしたコンペティションに取り組むことによって、座学した内容がどのように実際のデータ分析に応用されうるのか、データ分析コンペティションにはどのように取り組めばいいのか、といった事柄を体得することができます。
#
# 　今回は受講生の皆様にもこちらのコンペティションに取り組んでいただきます。受講生のレベルは各々に異なっていますが、今回こちらのコンペティションに取り組んでいただく意義は、それぞれのレベルに応じて以下のように想定されています。
#
# - **この講座で機械学習やデータ分析に入門する**：
#     - 機械学習を用いたデータ分析がどのような流れで行われるのかを概観する。
#     - この講座を通してこれからどのような内容を学んでいくのか把握する。
#
# - **機械学習技術についてある程度の知識はあるが、実際にデータ分析に応用したことはない**：
#     - 機械学習技術がどのようにデータ分析に応用されうるのか見る。
#     - データ分析に機械学習技術を応用するための試行錯誤を体験する。
#
# - **データ分析に取り組んだことはあるが、機械学習技術を応用したことはない**：
#     - 今までのデータ分析経験をどのように活用できるのか把握する。
#     - 機械学習技術によってデータ分析がどのように変わるのか知る。
#
# - **Kaggleや業務などで機械学習を用いたデータ分析に取り組んだことがある**：
#     - 初心に返って取り組むことで、データ分析の基礎を改めて確認する。
#     - 他の参加者との交流を通じて、新たな観点や知見を得る。

# %% [markdown]
# ## 目標
# 　Titanic号の乗客に関する様々な情報から、**その乗客が最終的に亡くなったかどうか**をできるだけ正しく予測してください。乗客の死亡/生存情報は、Perishedカラムの値に対応付けられています。Perishedカラムの値が1であれば死亡した、0であれば生存したということに対応しています。本コンペはオリジナルの"Titanic: Machine Learning from Disaster"コンペを模してはいるものの同一ではないため、一部カラムの命名や意味が異なります。下記のデータの項をよく読んで取り組むようにしてください。

# %% [markdown]
# ## データ
# 　データ分析コンペティションでは、一般的に**訓練データ**と**テストデータ**が与えられます。今回の場合、訓練データは**data/train.csv**、テストデータは**data/test.csv**となっています。
#
# 訓練データとテストデータは以下のような点で異なります。
# - 訓練データ：このデータによって機械学習モデルを学習させます。
# - テストデータ：このデータに対する予測を提出して、その精度を競います。
#
# 　含まれているデータの種類は以下のようになっています。
#
# 変数 |定義 |備考
# ---|---|---
# Perished |死亡したかどうか |0 = No, 1 = Yes
# Pclass |チケットのクラス |1 = 1st, 2 = 2nd, 3 = 3rd
# Name |名前 |
# Sex |性別 |
# Age	|年齢 |
# SibSp |乗船していた兄弟姉妹・配偶者の数	|
# Parch |乗船していた親・子供の数	|
# Ticket |チケット番号	|
# Fare |チケット料金	|
# Cabin |キャビン番号	|
# embarked |乗船した港	|C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# ## 評価指標
# 　今回のコンペティションでは、テストデータに対する予測の **正解率(accuracy)** を競っていただきます。

# %% [markdown]
# ## 提出/採点/順位
# 　予測は**Omnicampus**上で提出してください。提出するデータの形式は以下のようなcsvファイルとなります。
#
# PassengerID|Perished
# ---|---
# 892|0
# 893|1
# 894|0
# …|…
# 1307|0
# 1308|0
# 1309|0
#
# 　また**gender_submission.csv**がこの形式に準じた提出ファイルの例となっているので、参考にしてください。 提出ファイルがこの形式に準じていなかった場合にはスコアが-1となるので、そのような際は提出ファイルの形式を確認してみましょう。
#
# 　**提出回数**には制限はなく、何度でも提出可能です。
#
#   ただし、採点以下の記載にしたがって行われます。

# %% [markdown]
# ## 採点
# 採点は1日3回、日本時間の3時・15時・21時に実施されます。採点結果が反映されるまで約30分程度かかる場合があるため、採点結果を確認する際にはタイムラグが生じる可能性にご注意ください。
#
# コンペティション期間中の採点は、テストデータの一部に基づいて行われます。これは、「順位表に対する過学習」を避けるための措置です。採点結果に基づいて**Public Leaderboard**が更新されます。
#
# コンペティション終了後には、テストデータ全体を用いた採点が行われ、最終順位が決定します。この採点結果に基づいた順位表は**Private Leaderboard**と呼ばれます。

# %% [markdown]
# ## 順位
# 最終順位は、テストデータ全体に基づく**Private Leaderboard**の結果で決定されます。
#
# 順位の確定には、**最後に提出されたファイル**によって決定されます。
#
# 上位入賞者には、提出した予測を生成するコードの再現性を確認するため、**Google Colab上で動作するコード**の提出をお願いする予定です。これにより最終順位が確定されますので、協力をお願いいたします。

# %% [markdown]
# ## タイムライン
# 開始日、提出期限、順位発表の時期は別途アナウンスします。

# %% [markdown]
# ## ルール
# - **外部データ使用の禁止**
# 　データ分析においては、EDA（**beginner.ipynb**にて簡単に用語解説しています）やモデルの学習など全ての段階において外部データを使用しないでください。つまり今回のコンペティションでは、input/train.csvおよびinput/test.csvのみを使用して、データ分析に取り組んでください。事前学習済みモデルの利用も禁止です。
#
# - **Hand-Labelingの禁止**
# 　モデルではなく手作業で予測を作成することはHand-Labelingと呼ばれ、ほとんどのデータ分析コンペティションで禁止されています。今回のコンペティションでもこのルールを採用し、全てまたは一部のテストデータに対してHand-Labelingを行うことを禁止します。EDAの結果から導出したルールや特定の条件に基づき、**予測の一部を人為的に決定すること**もHand-Labelingに該当します。すべての予測はモデルによって生成されなければならず、手作業による予測は認められません。データの加工は再現可能な手法に基づき、提出する予測は他の同様の内容を持つデータに対しても適用可能なモデルによって**自動で行われる**必要があります。
#
# - **チームアップの禁止**
# 　本コンペティションでは、参加者同士のチームアップは禁止されています。**スコアを上げることを目的とした**受講生間の共同作業による予測の生成、モデルの作成、コードの作成は認められません。ただし、学びを深めるための公開された場での情報交換やディスカッションは奨励されています。この場合は、個別に協力するのではなく、他の受講生がアクセスできる場で行うことが推奨されます。
#
# - **再現性の確保**
# 　可能な限り予測の再現性を確保してください。再現性を保つためには、**乱数生成においてシード値を指定すること**が必要条件です。入門者は後述のbeginner.ipynbで作成したモデルのどの部分で乱数が用いられていてシード値が指定されているのか探してみましょう。用いられている機械学習ライブラリscikit-learnでは、一般的に乱数生成のシード値はrandom_stateという引数やアトリビュートで指定することとされています。
# 　「可能な限り」という表現がなされているのは、再現性がどうしても保てない場合が存在するためです。例えば、PyTorchというディープラーニングフレームワークがバージョンアップにより全体的に精度を落とすということがありました。この場合、バージョンアップ前に作成した予測をバージョンアップ後に再現するためには、バージョンダウンする必要があります。今回のコンペティションにおいては、再現性の確保のためにそこまでする必要はありません。
#
# - **Private Sharingの許可**
# 　データ分析コンペティションでは一般的に、公平性の観点から個人的な情報共有は厳しく規制されています。多くの場合、チームの結成を規定の方法で宣言した場合のみチーム内での情報共有が許可されます。チーム外の個人的な情報共有は**Private Sharing**と呼ばれ、固く禁じられています。
# 　しかし今回のコンペティションは入門者の参加するチュートリアルとしての位置付けであるため、Private Sharingの禁止は適用しません。身近に経験者がいれば積極的にアドバイスを求めても良いですし、オンラインで他の受講生と情報交換やディスカッションをしても構いません。ただしオンラインで他の受講生と情報交換やディスカッションをする際には、できるだけ個人的なやりとりではなく公開された場で行い、全ての受講生が知見を共有できるよう心がけてください。
#
# - **フォーク元(参考コード)の明記**
# 本コンペは非常にレベルの高く参考になるnotebookが沢山インターネットに報告されています。このような優秀な取り組みを探し、コードを解読することも一つの勉強ですので、ぜひ参考にしてください。他者のコードを参考にすること自体は全く問題ありません。 一方、GCIでは教育的な観点から、ご自身の取り組みと引用を区別していただいております。従って**コードを引用した際には、フォーク元を明示**してください。本コンペでは上位入賞対象者にはコードを開示していただいております。この際にフォーク元を開示して頂かず明らかに他者のコードであると発覚した場合には、入賞を取り消さざるを得ない可能性もあるので、自分がどのコードを参考にしたか記録するためにも自分の参考にしたnotebookは記録しておくようにしましょう。

# %% [markdown]
# ## 取り組み方
# 　機械学習を用いたデータ分析に取り組んだ経験のない受講生は、demo以下にある**beginner.ipynb**を上のセルから順に実行してみて、予測を作成するまでの流れを追ってみましょう。またこのようにして作成できた予測をOmnicampus上で提出してみましょう。
#  機械学習を用いたデータ分析に取り組んだ経験のある受講生や、意欲のある受講生は**professional.ipynb**を参考に予測をOmnicampusに提出してみましょう。こちらのnotebookにはどのような点で工夫が可能であるかというアドバイスも記述されているので、こうしたアドバイスを元に自分の工夫を加えてみても良いでしょう。
#
# 　beginner.ipynbやprofessional.ipynbの他にも、ブログ記事やKaggleで共有されているNotebook（ https://www.kaggle.com/c/titanic/notebooks ）の中には参考となるものが多く存在します。それらを参考としても良いでしょう。

# %% [markdown]
# ## 修了要件
# Public Leaderboard上で、beginner.ipynbを上のセルから順に実行して提出した際に表示される **「ベースラインスコア 0.675」を超えること**が修了要件の一つとなります。
# **最後に提出したファイルで判定**されますので、ご注意ください。
# Late Submissionで最後に提出したファイルのスコアがベースラインを上回った場合も、修了要件を満たします。
#
# ヒント: beginner.ipynbのあと、professional.ipynbを実行して提出してみましょう。

# %% [markdown]
# ## 参考文献
# Will Cukierski. (2012). Titanic - Machine Learning from Disaster. Kaggle. https://kaggle.com/competitions/titanic
